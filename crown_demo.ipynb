# %% [markdown]
# ## alpha-beta-CROWN verification

# %%
from verify_crown import verify_lyapunov_nn

# %%
duff.to(device)
crown_result = verify_lyapunov_nn(duff, device)

# %%
# Verify the Lyapunov function
print(f"Origin result: {crown_result['origin']}")
print("==============================================")
print(f"Positive result: {crown_result['positive']}\n\n")
print(f"Dim 0 negative: {crown_result['positive'][0][0]}\n")
print(f"Dim 0 positive: {crown_result['positive'][0][1]}\n\n")
print(f"Dim 1 negative: {crown_result['positive'][1][0]}\n")
print(f"Dim 1 positive: {crown_result['positive'][1][1]}\n\n")
